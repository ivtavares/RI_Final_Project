# %% [markdown]
# # Webscraping Instagram

# %% [markdown]
# ## Connection use Selenium

# %%
#import libraries
from selenium import webdriver
import urllib.request
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time

# %%
# Prepare the code for easily opening new browser window
driver_option = webdriver.ChromeOptions()
driver_option.add_argument(" — incognito")
chromedriver_path = '/home/igor/Estudos/Ciencia de Dados e Big Data/RI/chromedriver_linux'

def create_webdriver():
    return webdriver.Chrome(executable_path=chromedriver_path, options = driver_option)

# %%
#Open Google Chrome
driver = webdriver.Chrome(executable_path='/home/igor/Estudos/Ciencia de Dados e Big Data/RI/chromedriver_linux')
#Open page instagood
driver.get("https://www.instagram.com/explore/tags/instagood/")
photo = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]')
time.sleep(3)
ActionChains(driver).click(photo).perform()

# %%
try:
    print(driver.find_element_by_xpath("//h2[@class='BrX75']/a").text)
except:
    print('error')
# Out:
# error

# %%
try:
    video = driver.find_element_by_class_name('QvAa1')
    print(video.get_attribute('href'))
except:
    print('picture')
# Out:
# javascript:;

# %%
teste = driver.find_elements_by_xpath("//div[@class='KL4Bh']/img")
print(teste[len(teste)-2].get_attribute('alt'))
print(len(teste))
# Out:
# Image may contain: one or more people and indoor
# 41

# %%
#Change each photo
for i in range(1000):
    ActionChains(driver).send_keys(Keys.ARROW_RIGHT).perform()
    time.sleep(0.5)
    try:
        image = driver.find_elements_by_xpath("//div[@class='KL4Bh']/img")
        print(driver.find_element_by_xpath("//h2[@class='BrX75']/a").text)
        try:
            video = driver.find_element_by_class_name('QvAa1')
            print('Video is not categorized')
        except:
            if i >= len(image): 
                pos = len(image)-1
            else:
                pos = i-2
            print(image[pos].get_attribute('alt'))
    except:
        print('error')
    #print(image.get_attribute('alt'))
# Out:
# nataliaa.bae
# No photo description available.
# iam__mei_
# Image may contain: one or more people
# 0611cm
# Image may contain: one or more people and people standing
# madziowa_p
# No photo description available.
# _.n.t.v._
# Image may contain: one or more people
# shotzdelight
# Image may contain: one or more people
# error
# models_of_mh_09_
# Image may contain: sky, cloud, tree, twilight, outdoor and nature
# goki__1128
# Image may contain: one or more people
# george_moreno_mx
# Image may contain: one or more people, sunglasses and closeup
# misaki.s___0115
# Image may contain: one or more people, people standing, cloud, sky and outdoor
# fashionpeachblg
# Image may contain: one or more people and outdoor
# mahmud_junaid_ahmed
# Image may contain: one or more people, beard, closeup and indoor
# akki__photography007
# No photo description available.
# futura_36
# Video is not categorized
# ming_hana0302
# Image may contain: one or more people, hat and closeup
# kidz.asn.olshop
# Image may contain: text
# m_chan74
#
# blencustard
# Image may contain: dog and outdoor
# error
# m_iknm
# Image may contain: food
# _skid.__
# Image may contain: one or more people, sky, beach, ocean, outdoor and nature
# neko222taro
# Image may contain: plant
# lash.maisondetalon
# Image may contain: one or more people, people standing, shoes, hat and outdoor
# dankest.memes.dealer
# Image may contain: one or more people and people standing
# error
# syl__den
# Image may contain: text
# error
# alaiyekasabi
# Image may contain: one or more people and people standing
# nana_jxxu
# Image may contain: one or more people and closeup
# error
# corebenefits
# Image may contain: food and text
# error
# surihang.shop
# Image may contain: outdoor and water
# sonilal_paria
# Image may contain: one or more people
# diiegogomess
# Image may contain: one or more people, sky and outdoor
# ringringshg
# No photo description available.
# error
# _rajasya_
# Image may contain: one or more people
# tresq64
# Image may contain: one or more people, ring and closeup
# _shopmelmel
# Image may contain: text
# bjoern___r
# Image may contain: one or more people, people standing, shorts and outdoor
# m.b_show
# Image may contain: sky, tree and outdoor
# error
# yuronixn
# Video is not categorized
# larc_cesar
# Image may contain: one or more people
# error
# lav_andaa
# Image may contain: one or more people and sunglasses
# conorcreatives
# Image may contain: sky, ocean, outdoor, nature and water
# qdatlee
# Image may contain: ocean, sky, cloud, outdoor, water and nature
# 1o_13cmy
# Image may contain: one or more people
# iloaftoeat
# Image may contain: food
# error
# error
# frank_casado
# Image may contain: one or more people, sky and outdoor
# stepup_itsuvsu
# Image may contain: one or more people and beard
# error
# _.09_rio
# Image may contain: one or more people
# giuliaalucci
# No photo description available.
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# shosinger
# Image may contain: drink and indoor
# nikku8757
# Image may contain: 3 people, selfie
# error
# limonoenot
# Image may contain: night and outdoor
# mizael_huerta
# Image may contain: text
# jdgourmet
# Image may contain: fruit and food
# ax834my.jp
# Image may contain: text
# naamii_15
# No photo description available.
# siostrygolawskie
# No photo description available.
# mangalargamarchador1
# Image may contain: one or more people and outdoor
# error
# gillespudlo
# Image may contain: food
# dollbear_ly1
# Image may contain: one or more people
# prof.otograf
# Image may contain: sky, mountain, cloud, outdoor and nature
# poxasusuuu
# Image may contain: one or more people, selfie and closeup
# pastry_knight
# Image may contain: one or more people
# dr.marcotorrisi
# Image may contain: text
# spacecinemaofficial
# Image may contain: one or more people and closeup
# mp.soiferman
# Image may contain: one or more people and shoes
# what_you_thinking_
# Image may contain: cloud, sky, outdoor and nature
# matlabi_duniya111
# Image may contain: sky and outdoor
# 03__s__m
# Image may contain: cloud, sky, tree and outdoor
# u_rmy___
# Image may contain: one or more people and closeup
# a___kaz
# Image may contain: one or more people, child and selfie
# louisallenbodybuilding
# Video is not categorized
# pinksaintclothing
# Image may contain: one or more people, people standing and outdoor
# officialbrianburbano
# Image may contain: tree and outdoor
# insta._.min
# Image may contain: one or more people, phone, selfie and indoor
# error
# from_2nd_half
# Image may contain: cat and indoor
# h_hyeon_00
# Image may contain: one or more people, eyeglasses, selfie and closeup
# nik.mhi
# Image may contain: one or more people, people standing and outdoor
# iamaruuu_
# Image may contain: indoor
# minaling__
# Image may contain: one or more people, hat and indoor
# alexaner_mc_queen
# Image may contain: 1 person, selfie and closeup
# happivicky
# Image may contain: 1 person, sitting, table, drink and outdoor
# potter_hanedani
# Image may contain: one or more people and text
# error
# joy_b_a_r
# Image may contain: one or more people, sunglasses and closeup
# tiaradisal
# Image may contain: one or more people, people standing and outdoor
# not_badss
# Image may contain: one or more people, beard and closeup
# mr._life_racer_
# Image may contain: one or more people, people standing, sunglasses and outdoor
# _rc._.s.a.n.d.y.s.h.i.v.a._fl_
# Video is not categorized
# sandraalbinger
# Image may contain: text
# shubham_tuttix
# Video is not categorized
# softjendeuk
# Image may contain: one or more people, sky and outdoor
# assamese_cuties_and_hotties_
# Image may contain: one or more people, people sitting, shoes and outdoor
# klmbpics
# Image may contain: food
# erkekayakkabimodamm
# Image may contain: shoes
# ga_young_47
# Image may contain: one or more people, people sitting, phone, drink and indoor
# jimbob966
# No photo description available.
# goodplanetfoods
# Image may contain: food
# xiaomi.redmi.india
# Video is not categorized
# nitsbee
# Image may contain: one or more people, people standing and outdoor
# 19_dongin
# Image may contain: tree, night, sky and outdoor
# launocevicheria
# Image may contain: food
# error
# naell_leone
# Image may contain: 1 person, closeup
# pedrocavalcantefotografia
# Image may contain: motorcycle and outdoor
# ____akira__sato____20
# Image may contain: one or more people, people standing, outdoor and nature
# nukkadcafe
# Image may contain: plant
# arianagrande26mx
# Image may contain: text
# __huiji_an_
# Image may contain: one or more people, outdoor and water
# little_shira_dog
# No photo description available.
# hamza.touiri
# Image may contain: one or more people, mountain, sky, outdoor and nature
# error
# shaneshaw75
# Image may contain: sky, ocean, outdoor and water
# error
# elsamalric
# Image may contain: sky, tree, cloud and outdoor
# bradysbakery
# Image may contain: dessert and food
# cooper_unni
# Video is not categorized
# v70iirdesign
# No photo description available.
# annetta.8
# Image may contain: one or more people and closeup
# kayachka_
# Image may contain: text
# kyoto.x7010x
# Video is not categorized
# sandichen29
# Image may contain: 1 person, smiling, closeup
# artist_chrislobo
# Video is not categorized
# error
# marcovich__
# Image may contain: text
# equipo_panadragon
# Video is not categorized
# ulzzangshopru
# Image may contain: one or more people and closeup
# laughfeeds
# No photo description available.
# _mr.supersonic_
# Image may contain: night and text
# acoustic_kumar_19
# Video is not categorized
# jacehanley
# Video is not categorized
# error
# abiizz_abi
# Image may contain: one or more people, hat and outdoor
# __nikon_kid__
# Image may contain: plant
# dj_marvega
# Image may contain: one or more people and motorcycle
# villupuram_trendzz
# Image may contain: one or more people and outdoor
# rf_accessories
# No photo description available.
# justtosaylondon
# Image may contain: one or more people and closeup
# urbandistinction
# No photo description available.
# undeliveredpostcards
# Image may contain: outdoor and water
# m.bubuu
# Image may contain: one or more people
# nivedita_mukherjee
# No photo description available.
# santanabeachclubnaxos
# Image may contain: people sitting, table, ocean, outdoor and nature
# b_a_k__97
# Image may contain: one or more people, tree, shoes and outdoor
# error
# phil_marius
# Image may contain: outdoor
# error
# xx.jini
# Image may contain: food
# aghaty_dxb
# Image may contain: one or more people and people sitting
# eri__land
# Image may contain: one or more people, people eating, dessert, drink and food
# wndering_wnder1
# Image may contain: one or more people
# error
# roby_cook_95
# Image may contain: table and indoor
# _mv.90
# Image may contain: 1 person, sitting and outdoor
# _____miss.julia_____
# Image may contain: one or more people, people standing and shorts
# going__for__my__drem
# Image may contain: people sitting and outdoor
# bulanova.fan.club
# Image may contain: text
# fiesta_st_line
# Image may contain: car and outdoor
# mccake_s
# Image may contain: flower
# aesthet.pic
# Image may contain: food
# error
# 0ming0_523
# Image may contain: one or more people and outdoor
# tommys02
# Image may contain: one or more people, people standing and outdoor
# chathuranga_kodithuwakku
# Image may contain: one or more people, car and outdoor
# error
# official_ashu_kk
# Image may contain: one or more people, people sitting, shoes and outdoor
# rgj_rishabh
# Image may contain: one or more people
# valentina_rendina
# Image may contain: one or more people, people standing and shorts
# hadise_algul
# Image may contain: one or more people
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %% [markdown]
# #### Check these
# https://www.linkedin.com/pulse/scraping-instagram-selenuim-aman-khalid/
#
# https://selenium-python.readthedocs.io/api.html#module-selenium.webdriver.common.action_chains

# %%
#Close connection
#driver.quit()
